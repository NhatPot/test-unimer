# %% [markdown]
# # Uni-MuMER - Kaggle 2xT4 + DagsHub
#
# Train QLoRA, theo dõi metric trực tiếp bằng MLflow và lưu toàn bộ artifact lên DagsHub.

# %%
# 1. Cấu hình
import json
import os
import sys
import uuid
from pathlib import Path

from kaggle_secrets import UserSecretsClient

PROJECT_DIR = "/kaggle/working/test-unimer"
CONDA_DIR = "/kaggle/working/miniconda"
ENV_DIR = f"{CONDA_DIR}/envs/unimumer"
PYTHON = f"{ENV_DIR}/bin/python"

BASE_YAML_CONFIG = "train/Uni-MuMER-train.yaml"

# Nên để YAML runtime trong /kaggle/working để không ghi đè YAML gốc
RUNTIME_YAML_CONFIG = "/kaggle/working/runtime_Uni-MuMER-train.yaml"

YAML_CONFIG = BASE_YAML_CONFIG
NOTEBOOK_PATH = "uni-mumer-kaggle-dagshub v4.ipynb"
OUTPUT_DIR = "saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora"

DAGSHUB_USERNAME = "NhatPot"
DAGSHUB_REPO = "test-unimer"
EXPERIMENT_NAME = "Uni-MuMER-Qwen2.5-VL-3B"
RUN_UUID = uuid.uuid4().hex

# Cho notebook import được module nội bộ trong repo, ví dụ scripts.runtime_yaml
if PROJECT_DIR not in sys.path:
    sys.path.insert(0, PROJECT_DIR)

# Cho các lệnh subprocess cũng thấy project
os.environ["PYTHONPATH"] = PROJECT_DIR

# Lấy DagsHub token từ Kaggle Secrets
DAGSHUB_TOKEN = UserSecretsClient().get_secret("DAGSHUB_TOKEN")
if not DAGSHUB_TOKEN:
    raise RuntimeError("Kaggle Secret DAGSHUB_TOKEN is missing")

os.environ.update({
    "PROJECT_DIR": PROJECT_DIR,
    "CONDA_DIR": CONDA_DIR,
    "ENV_DIR": ENV_DIR,
    "PYTHON": PYTHON,
    "BASE_YAML_CONFIG": BASE_YAML_CONFIG,
    "RUNTIME_YAML_CONFIG": RUNTIME_YAML_CONFIG,
    "YAML_CONFIG": YAML_CONFIG,
    "NOTEBOOK_PATH": NOTEBOOK_PATH,
    "OUTPUT_DIR": OUTPUT_DIR,
    "RUN_UUID": RUN_UUID,
    "MLFLOW_TRACKING_URI": f"https://dagshub.com/{DAGSHUB_USERNAME}/{DAGSHUB_REPO}.mlflow",
    "MLFLOW_TRACKING_USERNAME": DAGSHUB_USERNAME,
    "MLFLOW_TRACKING_PASSWORD": DAGSHUB_TOKEN,
    "MLFLOW_EXPERIMENT_NAME": EXPERIMENT_NAME,
    "MLFLOW_FLATTEN_PARAMS": "TRUE",
    "MLFLOW_TAGS": json.dumps({
        "run_uuid": RUN_UUID,
        "source": "kaggle",
        "task": "sft",
        "dataset": "parquet_crohme_train",
    }),
})

print(f"Run UUID: {RUN_UUID}")
print(f"MLflow: {os.environ['MLFLOW_TRACKING_URI']}")
print(f"PROJECT_DIR: {PROJECT_DIR}")
print(f"PROJECT_DIR in sys.path: {PROJECT_DIR in sys.path}")
print(f"PYTHONPATH: {os.environ.get('PYTHONPATH')}")
print(f"runtime_yaml.py exists: {Path(PROJECT_DIR, 'scripts/runtime_yaml.py').exists()}")
# Out:
# Run UUID: 99f4ad6ddcbb4c53ae0f0fda13d2cfa2
# MLflow: https://dagshub.com/NhatPot/test-unimer.mlflow
# PROJECT_DIR: /kaggle/working/test-unimer
# PROJECT_DIR in sys.path: True
# PYTHONPATH: /kaggle/working/test-unimer
# runtime_yaml.py exists: False

# %%
# %%bash
# # 2. Tạo môi trường Python 3.10
# set -euo pipefail
#
# if [[ ! -x "$PYTHON" ]]; then
#   wget -q https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O /tmp/miniconda.sh
#   bash /tmp/miniconda.sh -b -f -p "$CONDA_DIR"
#   rm -f /tmp/miniconda.sh
#   "$CONDA_DIR/bin/conda" tos accept --override-channels --channel https://repo.anaconda.com/pkgs/main
#   "$CONDA_DIR/bin/conda" tos accept --override-channels --channel https://repo.anaconda.com/pkgs/r
#   "$CONDA_DIR/bin/conda" create -n unimumer python=3.10 -y
# fi
#
# "$PYTHON" --version
# Out:
# PREFIX=/kaggle/working/miniconda
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /kaggle/working/miniconda
# accepted Terms of Service for https://repo.anaconda.com/pkgs/main
# accepted Terms of Service for https://repo.anaconda.com/pkgs/r
# Jupyter detected...
# 2 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /kaggle/working/miniconda/envs/unimumer
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |           52_gnu           7 KB
#     ca-certificates-2026.5.14  |       h06a4308_0         107 KB
#     libexpat-2.8.1             |       h7354ed3_1         124 KB
#     libffi-3.4.8               |       h06d3fd0_3         137 KB
#     libgcc-15.2.0              |       h69a1729_8         803 KB
#     libgcc-ng-15.2.0           |       h166f726_8          28 KB
#     libnsl-2.0.0               |       h5eee18b_0          31 KB
#     libstdcxx-15.2.0           |       h39759b7_8         3.7 MB
#     libzlib-1.3.2              |       h47b2149_0          60 KB
#     openssl-3.5.7              |       h1b28b03_0         5.5 MB
#     packaging-26.0             |  py310h06a4308_0         165 KB
#     pip-26.1.2                 |     pyhc872135_0         1.1 MB
#     python-3.10.20             |       h17756b0_1        24.2 MB
#     setuptools-82.0.1          |  py310h06a4308_0         1.2 MB
#     sqlite-3.53.2              |       h795bf6d_0         1.2 MB
#     tzdata-2026b               |       he532380_0         118 KB
#     wheel-0.47.0               |  py310h06a4308_0          56 KB
#     zlib-1.3.2                 |       h47b2149_0          92 KB
#     ------------------------------------------------------------
#                                            Total:        38.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-52_gnu
#   bzip2              pkgs/main/linux-64::bzip2-1.0.8-h5eee18b_6
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2026.5.14-h06a4308_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.44-h9e0c5a2_3
#   libexpat           pkgs/main/linux-64::libexpat-2.8.1-h7354ed3_1
#   libffi             pkgs/main/linux-64::libffi-3.4.8-h06d3fd0_3
#   libgcc             pkgs/main/linux-64::libgcc-15.2.0-h69a1729_8
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-15.2.0-h166f726_8
#   libnsl             pkgs/main/linux-64::libnsl-2.0.0-h5eee18b_0
#   libstdcxx          pkgs/main/linux-64::libstdcxx-15.2.0-h39759b7_8
#   libuuid            pkgs/main/linux-64::libuuid-1.41.5-h5eee18b_0
#   libxcb             pkgs/main/linux-64::libxcb-1.17.0-h9b100fa_0
#   libzlib            pkgs/main/linux-64::libzlib-1.3.2-h47b2149_0
#   ncurses            pkgs/main/linux-64::ncurses-6.5-h7934f7d_0
#   openssl            pkgs/main/linux-64::openssl-3.5.7-h1b28b03_0
#   packaging          pkgs/main/linux-64::packaging-26.0-py310h06a4308_0
#   pip                pkgs/main/noarch::pip-26.1.2-pyhc872135_0
#   pthread-stubs      pkgs/main/linux-64::pthread-stubs-0.3-h0ce48e5_1
#   python             pkgs/main/linux-64::python-3.10.20-h17756b0_1
#   readline           pkgs/main/linux-64::readline-8.3-hc2a1206_0
#   setuptools         pkgs/main/linux-64::setuptools-82.0.1-py310h06a4308_0
#   sqlite             pkgs/main/linux-64::sqlite-3.53.2-h795bf6d_0
#   tk                 pkgs/main/linux-64::tk-8.6.15-h54e0aa7_0
#   tzdata             pkgs/main/noarch::tzdata-2026b-he532380_0
#   wheel              pkgs/main/linux-64::wheel-0.47.0-py310h06a4308_0
#   xorg-libx11        pkgs/main/linux-64::xorg-libx11-1.8.12-h9b100fa_1
#   xorg-libxau        pkgs/main/linux-64::xorg-libxau-1.0.12-h9b100fa_0
#   xorg-libxdmcp      pkgs/main/linux-64::xorg-libxdmcp-1.1.5-h9b100fa_0
#   xorg-xorgproto     pkgs/main/linux-64::xorg-xorgproto-2024.1-h5eee18b_1
#   xz                 pkgs/main/linux-64::xz-5.8.2-h448239c_0
#   zlib               pkgs/main/linux-64::zlib-1.3.2-h47b2149_0
#
#
#
# python-3.10.20       | 24.2 MB   |            |   0%
# openssl-3.5.7        | 5.5 MB    |            |   0%
#
# libstdcxx-15.2.0     | 3.7 MB    |            |   0%
#
#
# sqlite-3.53.2        | 1.2 MB    |            |   0%
#
#
#
# setuptools-82.0.1    | 1.2 MB    |            |   0%
#
#
#
#
# pip-26.1.2           | 1.1 MB    |            |   0%
#
#
#
#
#
# libgcc-15.2.0        | 803 KB    |            |   0%
#
#
#
#
#
#
# packaging-26.0       | 165 KB    |            |   0%
#
#
#
#
#
#
#
# libffi-3.4.8         | 137 KB    |            |   0%
#
#
#
#
#
#
#
#
# libexpat-2.8.1       | 124 KB    |            |   0%
#
#
#
#
#
#
#
#
#
# tzdata-2026b         | 118 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 107 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.3.2           | 92 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.2        | 60 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.47.0         | 56 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.0         | 31 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.2.0     | 28 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-5.1    | 7 KB      |            |   0%
# python-3.10.20       | 24.2 MB   |            |   0%
#
# libstdcxx-15.2.0     | 3.7 MB    |            |   0%
#
#
#
# setuptools-82.0.1    | 1.2 MB    | 1          |   1%
#
#
# sqlite-3.53.2        | 1.2 MB    | 1          |   1%
# python-3.10.20       | 24.2 MB   | #3         |  14%
#
# libstdcxx-15.2.0     | 3.7 MB    | ######9    |  69%
#
#
#
# setuptools-82.0.1    | 1.2 MB    | ########## | 100%
#
#
#
# setuptools-82.0.1    | 1.2 MB    | ########## | 100%
#
#
# sqlite-3.53.2        | 1.2 MB    | ########## | 100%
#
#
# sqlite-3.53.2        | 1.2 MB    | ########## | 100%
#
#
#
#
# pip-26.1.2           | 1.1 MB    | 1          |   1%
#
#
#
#
#
# python-3.10.20       | 24.2 MB   | ##4        |  24%
#
#
#
#
#
# libgcc-15.2.0        | 803 KB    | ########## | 100%
#
#
#
#
# python-3.10.20       | 24.2 MB   | ###5       |  35%
#
# libstdcxx-15.2.0     | 3.7 MB    | ########## | 100%
#
#
#
#
#
#
# packaging-26.0       | 165 KB    | 9          |  10%
#
#
#
#
#
#
#
# libffi-3.4.8         | 137 KB    | #1         |  12%
#
#
#
#
#
#
# packaging-26.0       | 165 KB    | ########## | 100%
#
#
#
#
#
#
#
# libffi-3.4.8         | 137 KB    | ########## | 100%
#
#
# sqlite-3.53.2        | 1.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# libexpat-2.8.1       | 124 KB    | #2         |  13%
#
#
#
#
#
#
#
#
# libexpat-2.8.1       | 124 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# tzdata-2026b         | 118 KB    | #3         |  14%
#
#
#
#
#
#
#
#
#
#
# python-3.10.20       | 24.2 MB   | ####5      |  46%
#
#
#
#
#
#
#
#
#
# tzdata-2026b         | 118 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 107 KB    | ########## | 100%
# openssl-3.5.7        | 5.5 MB    | ########## | 100%
# openssl-3.5.7        | 5.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.2        | 60 KB     | ##6        |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.47.0         | 56 KB     | ##8        |  28%
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.2        | 60 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.3.2           | 92 KB     | #7         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.47.0         | 56 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.20       | 24.2 MB   | #####8     |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-5.1    | 7 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-5.1    | 7 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.2.0     | 28 KB     | #####7     |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.2.0     | 28 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.0         | 31 KB     | #####1     |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.0         | 31 KB     | ########## | 100%
#
#
#
#
#
# libgcc-15.2.0        | 803 KB    | ########## | 100%
#
#
#
#
#
# python-3.10.20       | 24.2 MB   | #########  |  90%
#
# libstdcxx-15.2.0     | 3.7 MB    | ########## | 100%
#
#
#
#
#
#
# packaging-26.0       | 165 KB    | ########## | 100%
#
#
#
#
#
#
# packaging-26.0       | 165 KB    | ########## | 100%
#
#
#
#
# pip-26.1.2           | 1.1 MB    | ########## | 100%
#
#
#
#
# python-3.10.20       | 24.2 MB   | ########## | 100%
#
#
#
#
#
#
#
#
# libexpat-2.8.1       | 124 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# libexpat-2.8.1       | 124 KB    | ########## | 100%
#
#
#
#
#
#
#
# libffi-3.4.8         | 137 KB    | ########## | 100%
#
#
#
#
#
#
#
# libffi-3.4.8         | 137 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 107 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2026 | 107 KB    | ########## | 100%
#
#
#
# setuptools-82.0.1    | 1.2 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.2        | 60 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.2        | 60 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.47.0         | 56 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.47.0         | 56 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.3.2           | 92 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# zlib-1.3.2           | 92 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# _openmp_mutex-5.1    | 7 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
# tzdata-2026b         | 118 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# tzdata-2026b         | 118 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.2.0     | 28 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgcc-ng-15.2.0     | 28 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.0         | 31 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.0         | 31 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                       done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# #
# # To activate this environment, use
# #
# #     $ conda activate unimumer
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
# Channel "defaults" has the following notices:
#   [info] -- Tue Jun  9 00:00:00 2026
#   PyTorch 2.12 with CUDA support is now available to install with your current channel (Anaconda Main). Learn more: https://anaconda.org/main/pytorch?utm_source=channel_notices
#
# Python 3.10.20
# ==> WARNING: A newer version of conda exists. <==
#     current version: 26.3.2
#     latest version: 26.5.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
# %%bash
# # 3. Lấy source code
# set -euo pipefail
#
# if [[ ! -d "$PROJECT_DIR/.git" ]]; then
#   git clone https://github.com/NhatPot/test-unimer.git "$PROJECT_DIR"
# fi
#
# git -C "$PROJECT_DIR" rev-parse --short HEAD
# Out:
# 69d68f9
# Cloning into '/kaggle/working/test-unimer'...

# %%
# %%bash
# # 3.5. Download test datasets từ Google Drive
# set -euo pipefail
#
# # Cài gdown nếu chưa có
# pip install -q gdown
#
# # Download và extract dataset
# cd "$PROJECT_DIR"
# if [[ ! -d "example_data/CROHME_TEST_IMAGES" ]]; then
#   echo "Downloading CROHME test images from Google Drive..."
#   gdown "1uHT7iOFHGASc9_HB-PhpIuJizlOUOg1L" -O crohme_test_images.zip
#
#   echo "Extracting images..."
#   unzip -q crohme_test_images.zip -d example_data/
#   rm crohme_test_images.zip
#
#   echo "✓ Test images downloaded and extracted"
# else
#   echo "✓ Test images already exist"
# fi
#
# # Verify
# ls -lh example_data/ | grep -i crohme
# Out:
# Downloading CROHME test images from Google Drive...
# Extracting images...
# ✓ Test images downloaded and extracted
# drwxr-xr-x 4 root root 4.0K Jun 24 13:14 CROHME
# drwxr-xr-x 4 root root 4.0K Jun 24 13:14 CROHME2023
# Downloading...
# From (original): https://drive.google.com/uc?id=1uHT7iOFHGASc9_HB-PhpIuJizlOUOg1L
# From (redirected): https://drive.google.com/uc?id=1uHT7iOFHGASc9_HB-PhpIuJizlOUOg1L&confirm=t&uuid=5d3c981b-e123-461a-9f0f-9d645ba3661b
# To: /kaggle/working/test-unimer/crohme_test_images.zip
# 100%|██████████| 1.63G/1.63G [00:20<00:00, 77.7MB/s]

# %%
# %%bash
# # 4. Cài dependency
# set -euo pipefail
# cd "$PROJECT_DIR"
# source "$CONDA_DIR/bin/activate" unimumer
#
# python --version
# python -m pip install -q -r requirements.txt
# python -m pip install -q -e train/LLaMA-Factory
# python -c "import torch, mlflow; print('GPU:', torch.cuda.get_device_name(0)); print('MLflow:', mlflow.__version__)"
# Out:
# Python 3.10.20
# GPU: Tesla T4
# MLflow: 3.14.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# prometheus-fastapi-instrumentator 8.0.2 requires starlette<2.0.0,>=1.0.0, but you have starlette 0.52.1 which is incompatible.

# %%
# 5. Runtime YAML Override (tùy chọn)
from scripts.runtime_yaml import prepare_runtime_yaml

USE_RUNTIME_YAML_OVERRIDE = True

YAML_OVERRIDES = {
    "dataset": "parquet_crohme_train",
    "max_samples": 3,
    "num_train_epochs": 3,
    "per_device_train_batch_size": 2,
    "gradient_accumulation_steps": 64,
    "learning_rate": 1.0e-4,
    "lora_rank": 64,
    "logging_steps": 1,
    "save_steps": 20,
    "output_dir": "saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora",
    
    # Để None nếu không muốn override
    "cutoff_len": None,
    "val_size": None,
    "per_device_eval_batch_size": None,
    "eval_steps": None,
    "save_total_limit": None,
    "lora_alpha": None,
    "lora_dropout": None,
    "warmup_ratio": None,
    "quantization_bit": None,
    "preprocessing_num_workers": None,
    "dataloader_num_workers": None,
    "bf16": None,
    "fp16": None,
}

YAML_CONFIG, OUTPUT_DIR, YAML_DATA = prepare_runtime_yaml(
    project_dir=PROJECT_DIR,
    base_yaml_config=BASE_YAML_CONFIG,
    runtime_yaml_config=RUNTIME_YAML_CONFIG,
    use_override=USE_RUNTIME_YAML_OVERRIDE,
    overrides=YAML_OVERRIDES,
    strict_keys=True,
)

# Cập nhật biến môi trường
mlflow_tags = json.loads(os.environ["MLFLOW_TAGS"])
mlflow_tags.update({
    "dataset": str(YAML_DATA.get("dataset", "")),
    "yaml_config": YAML_CONFIG,
    "yaml_override": str(USE_RUNTIME_YAML_OVERRIDE).lower(),
})

os.environ.update({
    "YAML_CONFIG": YAML_CONFIG,
    "OUTPUT_DIR": OUTPUT_DIR,
    "MLFLOW_TAGS": json.dumps(mlflow_tags),
})
# Out:
# Runtime YAML Override: ON
# YAML gốc: /kaggle/working/test-unimer/train/Uni-MuMER-train.yaml
# YAML dùng để train: /kaggle/working/runtime_Uni-MuMER-train.yaml
# Các key đã đổi:
#   max_samples: 2 -> 3

# %%
# %%bash
# # 6. Kiểm tra DagsHub trước khi train
# set -euo pipefail
# cd "$PROJECT_DIR"
# source "$CONDA_DIR/bin/activate" unimumer
#
# python scripts/dagshub_logger.py check --experiment "$MLFLOW_EXPERIMENT_NAME"
# Out:
# 🏃 View run bald-snake-98 at: https://dagshub.com/NhatPot/test-unimer.mlflow/#/experiments/1/runs/6d886a9541b04107b67688a6a7ed4784
# 🧪 View experiment at: https://dagshub.com/NhatPot/test-unimer.mlflow/#/experiments/1
# DagsHub MLflow connection OK: https://dagshub.com/NhatPot/test-unimer.mlflow

# %%
# %%bash
# # 7. Training
# set -euo pipefail
# cd "$PROJECT_DIR"
# source "$CONDA_DIR/bin/activate" unimumer
#
# echo "Python: $(command -v python)"
# echo "Torchrun: $(command -v torchrun)"
# MPLBACKEND=Agg llamafactory-cli train "$YAML_CONFIG" "run_name=uni-mumer-${RUN_UUID:0:8}"
# Out:
# Python: /kaggle/working/miniconda/envs/unimumer/bin/python
# Torchrun: /kaggle/working/miniconda/envs/unimumer/bin/torchrun
# [INFO|2026-06-24 13:20:47] llamafactory.launcher:143 >> Initializing 2 distributed tasks at: 127.0.0.1:54281
# [WARNING|2026-06-24 13:20:57] llamafactory.hparams.parser:148 >> We recommend enable `upcast_layernorm` in quantized training.
# [INFO|2026-06-24 13:20:57] llamafactory.hparams.parser:143 >> Set `ddp_find_unused_parameters` to False in DDP training since LoRA is enabled.
# [INFO|2026-06-24 13:20:57] llamafactory.hparams.parser:465 >> Process rank: 0, world size: 2, device: cuda:0, distributed training: True, compute dtype: torch.float16
# [INFO|2026-06-24 13:20:57] llamafactory.hparams.parser:465 >> Process rank: 1, world size: 2, device: cuda:1, distributed training: True, compute dtype: torch.float16
# [INFO|2026-06-24 13:21:01] llamafactory.data.loader:143 >> Loading dataset phxember/Uni-MuMER-Data...
# training example:
# input_ids:
# [151644, 8948, 198, 2610, 525, 264, 10950, 17847, 13, 151645, 198, 151644, 872, 198, 151652, 151655, 151655, 151655, 151655, 151653, 40, 614, 458, 2168, 315, 264, 98389, 35972, 7493, 13, 5209, 3270, 700, 279, 7493, 315, 279, 14806, 304, 279, 2168, 1667, 97913, 3561, 13, 151645, 198, 151644, 77091, 198, 80, 151645, 198]
# inputs:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|vision_end|>I have an image of a handwritten mathematical expression. Please write out the expression of the formula in the image using LaTeX format.<|im_end|>
# <|im_start|>assistant
# q<|im_end|>
#
# label_ids:
# [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, 80, 151645, 198]
# labels:
# q<|im_end|>
#
# eval example:
# input_ids:
# [151644, 8948, 198, 2610, 525, 264, 10950, 17847, 13, 151645, 198, 151644, 872, 198, 151652, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151655, 151653, 40, 614, 458, 2168, 315, 264, 98389, 35972, 7493, 13, 5209, 3270, 700, 279, 7493, 315, 279, 14806, 304, 279, 2168, 1667, 97913, 3561, 13, 151645, 198, 151644, 77091, 198, 74, 481, 1124, 1242, 297, 151645, 198]
# inputs:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# <|vision_start|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|image_pad|><|vision_end|>I have an image of a handwritten mathematical expression. Please write out the expression of the formula in the image using LaTeX format.<|im_end|>
# <|im_start|>assistant
# k - \sum o<|im_end|>
#
# label_ids:
# [-100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, -100, 74, 481, 1124, 1242, 297, 151645, 198]
# labels:
# k - \sum o<|im_end|>
#
# [INFO|2026-06-24 13:21:07] llamafactory.model.model_utils.quantization:143 >> Quantizing model to 4 bit with bitsandbytes.
# [INFO|2026-06-24 13:21:07] llamafactory.model.model_utils.kv_cache:143 >> KV cache is disabled during training.
# [INFO|2026-06-24 13:22:03] llamafactory.model.model_utils.checkpointing:143 >> Gradient checkpointing enabled.
# [INFO|2026-06-24 13:22:03] llamafactory.model.model_utils.visual:143 >> Casting multimodal projector outputs in torch.float16.
# [INFO|2026-06-24 13:22:03] llamafactory.model.model_utils.attention:143 >> Using torch SDPA for faster training and inference.
# [INFO|2026-06-24 13:22:03] llamafactory.model.adapter:143 >> Upcasting trainable params to float32.
# [INFO|2026-06-24 13:22:03] llamafactory.model.adapter:143 >> Fine-tuning method: LoRA
# [INFO|2026-06-24 13:22:03] llamafactory.model.model_utils.misc:143 >> Found linear modules: qkv,v_proj,up_proj,o_proj,gate_proj,k_proj,proj,down_proj,q_proj
# [INFO|2026-06-24 13:22:05] llamafactory.model.loader:143 >> trainable params: 164,339,712 || all params: 3,918,962,688 || trainable%: 4.1934
# [WARNING|2026-06-24 13:22:07] llamafactory.train.callbacks:154 >> Previous trainer log in this folder will be deleted.
# {'loss': 0.0126, 'grad_norm': 0.01600382663309574, 'learning_rate': 0.0, 'epoch': 1.0}
# {'loss': 0.0126, 'grad_norm': 0.01603768765926361, 'learning_rate': 0.0001, 'epoch': 2.0}
# {'loss': 0.0083, 'grad_norm': 0.011659287847578526, 'learning_rate': 5e-05, 'epoch': 3.0}
# {'train_runtime': 11.066, 'train_samples_per_second': 0.542, 'train_steps_per_second': 0.271, 'train_loss': 0.011186630154649416, 'epoch': 3.0}
# 🏃 View run uni-mumer-99f4ad6d at: https://dagshub.com/NhatPot/test-unimer.mlflow/#/experiments/1/runs/c80a0cb7c28647ae97c30df97b365328
# 🧪 View experiment at: https://dagshub.com/NhatPot/test-unimer.mlflow/#/experiments/1
# ***** train metrics *****
#   effective_tokens_per_sec =    28.6011
#   epoch                    =        3.0
#   total_flos               =    38707GF
#   train_loss               =     0.0112
#   train_runtime            = 0:00:11.06
#   train_samples_per_second =      0.542
#   train_steps_per_second   =      0.271
# Figure saved at: saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/training_loss.png
# [WARNING|2026-06-24 13:22:22] llamafactory.extras.ploting:148 >> No metric eval_loss to plot.
# [WARNING|2026-06-24 13:22:22] llamafactory.extras.ploting:148 >> No metric eval_accuracy to plot.
# ***** eval metrics *****
#   epoch                   =        3.0
#   eval_accuracy           =     0.5714
#   eval_loss               =     1.5436
#   eval_runtime            = 0:00:00.85
#   eval_samples_per_second =      1.175
#   eval_steps_per_second   =      1.175
# 🏃 View run legendary-bat-756 at: https://dagshub.com/NhatPot/test-unimer.mlflow/#/experiments/1/runs/958245c3bd6446e690e5e7be909fabe6
# 🧪 View experiment at: https://dagshub.com/NhatPot/test-unimer.mlflow/#/experiments/1
# W0624 13:20:49.122000 407 site-packages/torch/distributed/run.py:792]
# W0624 13:20:49.122000 407 site-packages/torch/distributed/run.py:792] *****************************************
# W0624 13:20:49.122000 407 site-packages/torch/distributed/run.py:792] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0624 13:20:49.122000 407 site-packages/torch/distributed/run.py:792] *****************************************
# [INFO|tokenization_utils_base.py:2023] 2026-06-24 13:20:58,596 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-VL-3B-Instruct/snapshots/66285546d2b821cf421d4f5eb2576359d3770cd3/vocab.json
# [INFO|tokenization_utils_base.py:2023] 2026-06-24 13:20:58,596 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-VL-3B-Instruct/snapshots/66285546d2b821cf421d4f5eb2576359d3770cd3/merges.txt
# [INFO|tokenization_utils_base.py:2023] 2026-06-24 13:20:58,596 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-VL-3B-Instruct/snapshots/66285546d2b821cf421d4f5eb2576359d3770cd3/tokenizer.json
# [INFO|tokenization_utils_base.py:2023] 2026-06-24 13:20:58,596 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2023] 2026-06-24 13:20:58,596 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2023] 2026-06-24 13:20:58,596 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-VL-3B-Instruct/snapshots/66285546d2b821cf421d4f5eb2576359d3770cd3/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2023] 2026-06-24 13:20:58,596 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2299] 2026-06-24 13:20:58,985 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [INFO|image_processing_base.py:380] 2026-06-24 13:20:59,269 >> loading configuration file preprocessor_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-VL-3B-Instruct/snapshots/66285546d2b821cf421d4f5eb2576359d3770cd3/preprocessor_config.json
# [INFO|image_processing_base.py:380] 2026-06-24 13:20:59,364 >> loading configuration file preprocessor_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-VL-3B-Instruct/snapshots/66285546d2b821cf421d4f5eb2576359d3770cd3/preprocessor_config.json
# [INFO|image_processing_base.py:433] 2026-06-24 13:20:59,372 >> Image processor Qwen2VLImageProcessorFast {
#   "crop_size": null,
#   "data_format": "channels_first",
#   "default_to_square": true,
#   "device": null,
#   "do_center_crop": null,
#   "do_convert_rgb": true,
#   "do_normalize": true,
#   "do_rescale": true,
#   "do_resize": true,
#   "image_mean": [
#     0.48145466,
#     0.4578275,
#     0.40821073
#   ],
#   "image_processor_type": "Qwen2VLImageProcessorFast",
#   "image_std": [
#     0.26862954,
#     0.26130258,
#     0.27577711
#   ],
#   "input_data_format": null,
#   "max_pixels": 12845056,
#   "merge_size": 2,
#   "min_pixels": 3136,
#   "patch_size": 14,
#   "processor_class": "Qwen2_5_VLProcessor",
#   "resample": 3,
#   "rescale_factor": 0.00392156862745098,
#   "return_tensors": null,
#   "size": {
#     "longest_edge": 12845056,
#     "shortest_edge": 3136
#   },
#   "temporal_patch_size": 2
# }
#
# [INFO|tokenization_utils_base.py:2023] 2026-06-24 13:20:59,551 >> loading file vocab.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-VL-3B-Instruct/snapshots/66285546d2b821cf421d4f5eb2576359d3770cd3/vocab.json
# [INFO|tokenization_utils_base.py:2023] 2026-06-24 13:20:59,551 >> loading file merges.txt from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-VL-3B-Instruct/snapshots/66285546d2b821cf421d4f5eb2576359d3770cd3/merges.txt
# [INFO|tokenization_utils_base.py:2023] 2026-06-24 13:20:59,551 >> loading file tokenizer.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-VL-3B-Instruct/snapshots/66285546d2b821cf421d4f5eb2576359d3770cd3/tokenizer.json
# [INFO|tokenization_utils_base.py:2023] 2026-06-24 13:20:59,551 >> loading file added_tokens.json from cache at None
# [INFO|tokenization_utils_base.py:2023] 2026-06-24 13:20:59,551 >> loading file special_tokens_map.json from cache at None
# [INFO|tokenization_utils_base.py:2023] 2026-06-24 13:20:59,551 >> loading file tokenizer_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-VL-3B-Instruct/snapshots/66285546d2b821cf421d4f5eb2576359d3770cd3/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2023] 2026-06-24 13:20:59,551 >> loading file chat_template.jinja from cache at None
# [INFO|tokenization_utils_base.py:2299] 2026-06-24 13:20:59,931 >> Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# [WARNING|logging.py:328] 2026-06-24 13:21:00,109 >> You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# [INFO|video_processing_utils.py:629] 2026-06-24 13:21:00,109 >> loading configuration file preprocessor_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-VL-3B-Instruct/snapshots/66285546d2b821cf421d4f5eb2576359d3770cd3/preprocessor_config.json
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# [INFO|configuration_utils.py:698] 2026-06-24 13:21:00,217 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-VL-3B-Instruct/snapshots/66285546d2b821cf421d4f5eb2576359d3770cd3/config.json
# [INFO|configuration_utils.py:770] 2026-06-24 13:21:00,221 >> Model config Qwen2_5_VLConfig {
#   "architectures": [
#     "Qwen2_5_VLForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 2048,
#   "image_token_id": 151655,
#   "initializer_range": 0.02,
#   "intermediate_size": 11008,
#   "max_position_embeddings": 128000,
#   "max_window_layers": 70,
#   "model_type": "qwen2_5_vl",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 36,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": {
#     "mrope_section": [
#       16,
#       24,
#       24
#     ],
#     "rope_type": "default",
#     "type": "default"
#   },
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "text_config": {
#     "architectures": [
#       "Qwen2_5_VLForConditionalGeneration"
#     ],
#     "attention_dropout": 0.0,
#     "bos_token_id": 151643,
#     "eos_token_id": 151645,
#     "hidden_act": "silu",
#     "hidden_size": 2048,
#     "image_token_id": null,
#     "initializer_range": 0.02,
#     "intermediate_size": 11008,
#     "max_position_embeddings": 128000,
#     "max_window_layers": 70,
#     "model_type": "qwen2_5_vl_text",
#     "num_attention_heads": 16,
#     "num_hidden_layers": 36,
#     "num_key_value_heads": 2,
#     "rms_norm_eps": 1e-06,
#     "rope_scaling": {
#       "mrope_section": [
#         16,
#         24,
#         24
#       ],
#       "rope_type": "default",
#       "type": "default"
#     },
#     "rope_theta": 1000000.0,
#     "sliding_window": 32768,
#     "tie_word_embeddings": true,
#     "torch_dtype": "bfloat16",
#     "use_cache": true,
#     "use_sliding_window": false,
#     "video_token_id": null,
#     "vision_end_token_id": 151653,
#     "vision_start_token_id": 151652,
#     "vision_token_id": 151654,
#     "vocab_size": 151936
#   },
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.52.4",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "video_token_id": 151656,
#   "vision_config": {
#     "depth": 32,
#     "fullatt_block_indexes": [
#       7,
#       15,
#       23,
#       31
#     ],
#     "hidden_act": "silu",
#     "hidden_size": 1280,
#     "in_channels": 3,
#     "in_chans": 3,
#     "initializer_range": 0.02,
#     "intermediate_size": 3420,
#     "model_type": "qwen2_5_vl",
#     "num_heads": 16,
#     "out_hidden_size": 2048,
#     "patch_size": 14,
#     "spatial_merge_size": 2,
#     "spatial_patch_size": 14,
#     "temporal_patch_size": 2,
#     "tokens_per_second": 2,
#     "window_size": 112
#   },
#   "vision_end_token_id": 151653,
#   "vision_start_token_id": 151652,
#   "vision_token_id": 151654,
#   "vocab_size": 151936
# }
#
# [INFO|video_processing_utils.py:629] 2026-06-24 13:21:00,406 >> loading configuration file preprocessor_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-VL-3B-Instruct/snapshots/66285546d2b821cf421d4f5eb2576359d3770cd3/preprocessor_config.json
# [INFO|video_processing_utils.py:683] 2026-06-24 13:21:00,407 >> Video processor Qwen2VLVideoProcessor {
#   "_valid_kwargs_names": [
#     "do_convert_rgb",
#     "do_resize",
#     "size",
#     "size_divisor",
#     "default_to_square",
#     "resample",
#     "do_rescale",
#     "rescale_factor",
#     "do_normalize",
#     "image_mean",
#     "image_std",
#     "do_pad",
#     "do_center_crop",
#     "crop_size",
#     "data_format",
#     "input_data_format",
#     "device",
#     "min_pixels",
#     "max_pixels",
#     "patch_size",
#     "temporal_patch_size",
#     "merge_size"
#   ],
#   "crop_size": null,
#   "data_format": "channels_first",
#   "default_to_square": true,
#   "device": null,
#   "do_center_crop": null,
#   "do_convert_rgb": true,
#   "do_normalize": true,
#   "do_pad": null,
#   "do_rescale": true,
#   "do_resize": true,
#   "image_mean": [
#     0.48145466,
#     0.4578275,
#     0.40821073
#   ],
#   "image_processor_type": "Qwen2VLImageProcessor",
#   "image_std": [
#     0.26862954,
#     0.26130258,
#     0.27577711
#   ],
#   "input_data_format": null,
#   "max_pixels": 12845056,
#   "merge_size": 2,
#   "min_pixels": 3136,
#   "model_valid_processing_keys": [
#     "do_convert_rgb",
#     "do_resize",
#     "size",
#     "size_divisor",
#     "default_to_square",
#     "resample",
#     "do_rescale",
#     "rescale_factor",
#     "do_normalize",
#     "image_mean",
#     "image_std",
#     "do_pad",
#     "do_center_crop",
#     "crop_size",
#     "data_format",
#     "input_data_format",
#     "device",
#     "min_pixels",
#     "max_pixels",
#     "patch_size",
#     "temporal_patch_size",
#     "merge_size"
#   ],
#   "patch_size": 14,
#   "processor_class": "Qwen2_5_VLProcessor",
#   "resample": 3,
#   "rescale_factor": 0.00392156862745098,
#   "size": {
#     "longest_edge": 12845056,
#     "shortest_edge": 3136
#   },
#   "size_divisor": null,
#   "temporal_patch_size": 2,
#   "video_processor_type": "Qwen2VLVideoProcessor"
# }
#
# [INFO|processing_utils.py:990] 2026-06-24 13:21:01,513 >> Processor Qwen2_5_VLProcessor:
# - image_processor: Qwen2VLImageProcessorFast {
#   "crop_size": null,
#   "data_format": "channels_first",
#   "default_to_square": true,
#   "device": null,
#   "do_center_crop": null,
#   "do_convert_rgb": true,
#   "do_normalize": true,
#   "do_rescale": true,
#   "do_resize": true,
#   "image_mean": [
#     0.48145466,
#     0.4578275,
#     0.40821073
#   ],
#   "image_processor_type": "Qwen2VLImageProcessorFast",
#   "image_std": [
#     0.26862954,
#     0.26130258,
#     0.27577711
#   ],
#   "input_data_format": null,
#   "max_pixels": 12845056,
#   "merge_size": 2,
#   "min_pixels": 3136,
#   "patch_size": 14,
#   "processor_class": "Qwen2_5_VLProcessor",
#   "resample": 3,
#   "rescale_factor": 0.00392156862745098,
#   "return_tensors": null,
#   "size": {
#     "longest_edge": 12845056,
#     "shortest_edge": 3136
#   },
#   "temporal_patch_size": 2
# }
#
# - tokenizer: Qwen2TokenizerFast(name_or_path='Qwen/Qwen2.5-VL-3B-Instruct', vocab_size=151643, model_max_length=131072, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'eos_token': '<|im_end|>', 'pad_token': '<|endoftext|>', 'additional_special_tokens': ['<|im_start|>', '<|im_end|>', '<|object_ref_start|>', '<|object_ref_end|>', '<|box_start|>', '<|box_end|>', '<|quad_start|>', '<|quad_end|>', '<|vision_start|>', '<|vision_end|>', '<|vision_pad|>', '<|image_pad|>', '<|video_pad|>']}, clean_up_tokenization_spaces=False, added_tokens_decoder={
# 	151643: AddedToken("<|endoftext|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151644: AddedToken("<|im_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151645: AddedToken("<|im_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151646: AddedToken("<|object_ref_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151647: AddedToken("<|object_ref_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151648: AddedToken("<|box_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151649: AddedToken("<|box_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151650: AddedToken("<|quad_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151651: AddedToken("<|quad_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151652: AddedToken("<|vision_start|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151653: AddedToken("<|vision_end|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151654: AddedToken("<|vision_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151655: AddedToken("<|image_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151656: AddedToken("<|video_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=True),
# 	151657: AddedToken("<tool_call>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151658: AddedToken("</tool_call>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151659: AddedToken("<|fim_prefix|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151660: AddedToken("<|fim_middle|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151661: AddedToken("<|fim_suffix|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151662: AddedToken("<|fim_pad|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151663: AddedToken("<|repo_name|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# 	151664: AddedToken("<|file_sep|>", rstrip=False, lstrip=False, single_word=False, normalized=False, special=False),
# }
# )
# - video_processor: Qwen2VLVideoProcessor {
#   "_valid_kwargs_names": [
#     "do_convert_rgb",
#     "do_resize",
#     "size",
#     "size_divisor",
#     "default_to_square",
#     "resample",
#     "do_rescale",
#     "rescale_factor",
#     "do_normalize",
#     "image_mean",
#     "image_std",
#     "do_pad",
#     "do_center_crop",
#     "crop_size",
#     "data_format",
#     "input_data_format",
#     "device",
#     "min_pixels",
#     "max_pixels",
#     "patch_size",
#     "temporal_patch_size",
#     "merge_size"
#   ],
#   "crop_size": null,
#   "data_format": "channels_first",
#   "default_to_square": true,
#   "device": null,
#   "do_center_crop": null,
#   "do_convert_rgb": true,
#   "do_normalize": true,
#   "do_pad": null,
#   "do_rescale": true,
#   "do_resize": true,
#   "image_mean": [
#     0.48145466,
#     0.4578275,
#     0.40821073
#   ],
#   "image_processor_type": "Qwen2VLImageProcessor",
#   "image_std": [
#     0.26862954,
#     0.26130258,
#     0.27577711
#   ],
#   "input_data_format": null,
#   "max_pixels": 12845056,
#   "merge_size": 2,
#   "min_pixels": 3136,
#   "model_valid_processing_keys": [
#     "do_convert_rgb",
#     "do_resize",
#     "size",
#     "size_divisor",
#     "default_to_square",
#     "resample",
#     "do_rescale",
#     "rescale_factor",
#     "do_normalize",
#     "image_mean",
#     "image_std",
#     "do_pad",
#     "do_center_crop",
#     "crop_size",
#     "data_format",
#     "input_data_format",
#     "device",
#     "min_pixels",
#     "max_pixels",
#     "patch_size",
#     "temporal_patch_size",
#     "merge_size"
#   ],
#   "patch_size": 14,
#   "processor_class": "Qwen2_5_VLProcessor",
#   "resample": 3,
#   "rescale_factor": 0.00392156862745098,
#   "size": {
#     "longest_edge": 12845056,
#     "shortest_edge": 3136
#   },
#   "size_divisor": null,
#   "temporal_patch_size": 2,
#   "video_processor_type": "Qwen2VLVideoProcessor"
# }
#
#
# {
#   "processor_class": "Qwen2_5_VLProcessor"
# }
#
# [rank1]:[W624 13:21:01.672726796 ProcessGroupNCCL.cpp:4561] [PG ID 0 PG GUID 0 Rank 1]  using GPU 1 to perform barrier as devices used by this process are currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect. Specify device_ids in barrier() to force use of a particular device, or call init_process_group() with a device_id.
# Setting num_proc from 4 back to 1 for the train split to disable multiprocessing as it only contains one shard.
# Generating train split: 100%|██████████| 8834/8834 [00:00<00:00, 51033.80 examples/s]
# num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# Converting format of dataset (num_proc=3): 100%|██████████| 3/3 [00:00<00:00, 13.81 examples/s]
# [rank0]:[W624 13:21:05.824787472 ProcessGroupNCCL.cpp:4561] [PG ID 0 PG GUID 0 Rank 0]  using GPU 0 to perform barrier as devices used by this process are currently unknown. This can potentially cause a hang if this rank to GPU mapping is incorrect. Specify device_ids in barrier() to force use of a particular device, or call init_process_group() with a device_id.
# num_proc must be <= 2. Reducing num_proc to 2 for dataset of size 2.
# Running tokenizer on dataset (num_proc=2): 100%|██████████| 2/2 [00:01<00:00,  1.94 examples/s]
# num_proc must be <= 1. Reducing num_proc to 1 for dataset of size 1.
# Running tokenizer on dataset: 100%|██████████| 1/1 [00:00<00:00, 71.39 examples/s]
# num_proc must be <= 3. Reducing num_proc to 3 for dataset of size 3.
# num_proc must be <= 2. Reducing num_proc to 2 for dataset of size 2.
# [INFO|configuration_utils.py:698] 2026-06-24 13:21:07,971 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-VL-3B-Instruct/snapshots/66285546d2b821cf421d4f5eb2576359d3770cd3/config.json
# [INFO|configuration_utils.py:770] 2026-06-24 13:21:07,974 >> Model config Qwen2_5_VLConfig {
#   "architectures": [
#     "Qwen2_5_VLForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 2048,
#   "image_token_id": 151655,
#   "initializer_range": 0.02,
#   "intermediate_size": 11008,
#   "max_position_embeddings": 128000,
#   "max_window_layers": 70,
#   "model_type": "qwen2_5_vl",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 36,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": {
#     "mrope_section": [
#       16,
#       24,
#       24
#     ],
#     "rope_type": "default",
#     "type": "default"
#   },
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "text_config": {
#     "architectures": [
#       "Qwen2_5_VLForConditionalGeneration"
#     ],
#     "attention_dropout": 0.0,
#     "bos_token_id": 151643,
#     "eos_token_id": 151645,
#     "hidden_act": "silu",
#     "hidden_size": 2048,
#     "image_token_id": null,
#     "initializer_range": 0.02,
#     "intermediate_size": 11008,
#     "max_position_embeddings": 128000,
#     "max_window_layers": 70,
#     "model_type": "qwen2_5_vl_text",
#     "num_attention_heads": 16,
#     "num_hidden_layers": 36,
#     "num_key_value_heads": 2,
#     "rms_norm_eps": 1e-06,
#     "rope_scaling": {
#       "mrope_section": [
#         16,
#         24,
#         24
#       ],
#       "rope_type": "default",
#       "type": "default"
#     },
#     "rope_theta": 1000000.0,
#     "sliding_window": 32768,
#     "tie_word_embeddings": true,
#     "torch_dtype": "bfloat16",
#     "use_cache": true,
#     "use_sliding_window": false,
#     "video_token_id": null,
#     "vision_end_token_id": 151653,
#     "vision_start_token_id": 151652,
#     "vision_token_id": 151654,
#     "vocab_size": 151936
#   },
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.52.4",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "video_token_id": 151656,
#   "vision_config": {
#     "depth": 32,
#     "fullatt_block_indexes": [
#       7,
#       15,
#       23,
#       31
#     ],
#     "hidden_act": "silu",
#     "hidden_size": 1280,
#     "in_channels": 3,
#     "in_chans": 3,
#     "initializer_range": 0.02,
#     "intermediate_size": 3420,
#     "model_type": "qwen2_5_vl",
#     "num_heads": 16,
#     "out_hidden_size": 2048,
#     "patch_size": 14,
#     "spatial_merge_size": 2,
#     "spatial_patch_size": 14,
#     "temporal_patch_size": 2,
#     "tokens_per_second": 2,
#     "window_size": 112
#   },
#   "vision_end_token_id": 151653,
#   "vision_start_token_id": 151652,
#   "vision_token_id": 151654,
#   "vocab_size": 151936
# }
#
# num_proc must be <= 1. Reducing num_proc to 1 for dataset of size 1.
# [INFO|modeling_utils.py:1151] 2026-06-24 13:21:12,703 >> loading weights file model.safetensors from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-VL-3B-Instruct/snapshots/66285546d2b821cf421d4f5eb2576359d3770cd3/model.safetensors.index.json
# Fetching 2 files: 100%|██████████| 2/2 [00:38<00:00, 19.39s/it]
# [INFO|modeling_utils.py:2241] 2026-06-24 13:21:51,579 >> Instantiating Qwen2_5_VLForConditionalGeneration model under default dtype torch.float16.
# [INFO|configuration_utils.py:1135] 2026-06-24 13:21:51,582 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "use_cache": false
# }
#
# [INFO|modeling_utils.py:2241] 2026-06-24 13:21:51,583 >> Instantiating Qwen2_5_VisionTransformerPretrainedModel model under default dtype torch.float16.
# Fetching 2 files: 100%|██████████| 2/2 [00:38<00:00, 19.38s/it]
# [INFO|modeling_utils.py:2241] 2026-06-24 13:21:51,608 >> Instantiating Qwen2_5_VLTextModel model under default dtype torch.float16.
# Loading checkpoint shards: 100%|██████████| 2/2 [00:10<00:00,  5.49s/it]
# [INFO|modeling_utils.py:5131] 2026-06-24 13:22:03,010 >> All model checkpoint weights were used when initializing Qwen2_5_VLForConditionalGeneration.
#
# [INFO|modeling_utils.py:5139] 2026-06-24 13:22:03,010 >> All the weights of Qwen2_5_VLForConditionalGeneration were initialized from the model checkpoint at Qwen/Qwen2.5-VL-3B-Instruct.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use Qwen2_5_VLForConditionalGeneration for predictions without further training.
# [INFO|configuration_utils.py:1090] 2026-06-24 13:22:03,129 >> loading configuration file generation_config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-VL-3B-Instruct/snapshots/66285546d2b821cf421d4f5eb2576359d3770cd3/generation_config.json
# [INFO|configuration_utils.py:1135] 2026-06-24 13:22:03,130 >> Generate config GenerationConfig {
#   "bos_token_id": 151643,
#   "do_sample": true,
#   "eos_token_id": [
#     151645,
#     151643
#   ],
#   "pad_token_id": 151643,
#   "repetition_penalty": 1.05,
#   "temperature": 1e-06
# }
#
# Loading checkpoint shards: 100%|██████████| 2/2 [00:11<00:00,  5.73s/it]
# [INFO|trainer.py:756] 2026-06-24 13:22:07,227 >> Using auto half precision backend
# [INFO|trainer.py:2409] 2026-06-24 13:22:08,188 >> ***** Running training *****
# [INFO|trainer.py:2410] 2026-06-24 13:22:08,188 >>   Num examples = 2
# [INFO|trainer.py:2411] 2026-06-24 13:22:08,188 >>   Num Epochs = 3
# [INFO|trainer.py:2412] 2026-06-24 13:22:08,188 >>   Instantaneous batch size per device = 2
# [INFO|trainer.py:2415] 2026-06-24 13:22:08,188 >>   Total train batch size (w. parallel, distributed & accumulation) = 256
# [INFO|trainer.py:2416] 2026-06-24 13:22:08,188 >>   Gradient Accumulation steps = 64
# [INFO|trainer.py:2417] 2026-06-24 13:22:08,188 >>   Total optimization steps = 3
# [INFO|trainer.py:2418] 2026-06-24 13:22:08,200 >>   Number of trainable parameters = 164,339,712
#   0%|          | 0/3 [00:00<?, ?it/s][WARNING|logging.py:328] 2026-06-24 13:22:11,629 >> `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
# `loss_type=None` was set in the config but it is unrecognised.Using the default loss: `ForCausalLMLoss`.
# 100%|██████████| 3/3 [00:07<00:00,  2.23s/it][INFO|trainer.py:3993] 2026-06-24 13:22:16,855 >> Saving model checkpoint to saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/checkpoint-3
# [INFO|configuration_utils.py:698] 2026-06-24 13:22:17,166 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-VL-3B-Instruct/snapshots/66285546d2b821cf421d4f5eb2576359d3770cd3/config.json
# [INFO|configuration_utils.py:770] 2026-06-24 13:22:17,169 >> Model config Qwen2_5_VLConfig {
#   "architectures": [
#     "Qwen2_5_VLForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 2048,
#   "image_token_id": 151655,
#   "initializer_range": 0.02,
#   "intermediate_size": 11008,
#   "max_position_embeddings": 128000,
#   "max_window_layers": 70,
#   "model_type": "qwen2_5_vl",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 36,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": {
#     "mrope_section": [
#       16,
#       24,
#       24
#     ],
#     "rope_type": "default",
#     "type": "default"
#   },
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "text_config": {
#     "architectures": [
#       "Qwen2_5_VLForConditionalGeneration"
#     ],
#     "attention_dropout": 0.0,
#     "bos_token_id": 151643,
#     "eos_token_id": 151645,
#     "hidden_act": "silu",
#     "hidden_size": 2048,
#     "image_token_id": null,
#     "initializer_range": 0.02,
#     "intermediate_size": 11008,
#     "max_position_embeddings": 128000,
#     "max_window_layers": 70,
#     "model_type": "qwen2_5_vl_text",
#     "num_attention_heads": 16,
#     "num_hidden_layers": 36,
#     "num_key_value_heads": 2,
#     "rms_norm_eps": 1e-06,
#     "rope_scaling": {
#       "mrope_section": [
#         16,
#         24,
#         24
#       ],
#       "rope_type": "default",
#       "type": "default"
#     },
#     "rope_theta": 1000000.0,
#     "sliding_window": 32768,
#     "tie_word_embeddings": true,
#     "torch_dtype": "bfloat16",
#     "use_cache": true,
#     "use_sliding_window": false,
#     "video_token_id": null,
#     "vision_end_token_id": 151653,
#     "vision_start_token_id": 151652,
#     "vision_token_id": 151654,
#     "vocab_size": 151936
#   },
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.52.4",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "video_token_id": 151656,
#   "vision_config": {
#     "depth": 32,
#     "fullatt_block_indexes": [
#       7,
#       15,
#       23,
#       31
#     ],
#     "hidden_act": "silu",
#     "hidden_size": 1280,
#     "in_channels": 3,
#     "in_chans": 3,
#     "initializer_range": 0.02,
#     "intermediate_size": 3420,
#     "model_type": "qwen2_5_vl",
#     "num_heads": 16,
#     "out_hidden_size": 2048,
#     "patch_size": 14,
#     "spatial_merge_size": 2,
#     "spatial_patch_size": 14,
#     "temporal_patch_size": 2,
#     "tokens_per_second": 2,
#     "window_size": 112
#   },
#   "vision_end_token_id": 151653,
#   "vision_start_token_id": 151652,
#   "vision_token_id": 151654,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:2356] 2026-06-24 13:22:18,314 >> chat template saved in saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/checkpoint-3/chat_template.jinja
# [INFO|tokenization_utils_base.py:2525] 2026-06-24 13:22:18,315 >> tokenizer config file saved in saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/checkpoint-3/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2534] 2026-06-24 13:22:18,315 >> Special tokens file saved in saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/checkpoint-3/special_tokens_map.json
# [INFO|image_processing_base.py:260] 2026-06-24 13:22:18,507 >> Image processor saved in saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/checkpoint-3/preprocessor_config.json
# [INFO|tokenization_utils_base.py:2356] 2026-06-24 13:22:18,507 >> chat template saved in saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/checkpoint-3/chat_template.jinja
# [INFO|tokenization_utils_base.py:2525] 2026-06-24 13:22:18,508 >> tokenizer config file saved in saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/checkpoint-3/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2534] 2026-06-24 13:22:18,508 >> Special tokens file saved in saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/checkpoint-3/special_tokens_map.json
# [INFO|video_processing_utils.py:491] 2026-06-24 13:22:18,738 >> Video processor saved in saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/checkpoint-3/video_preprocessor_config.json
# [INFO|processing_utils.py:674] 2026-06-24 13:22:19,266 >> chat template saved in saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/checkpoint-3/chat_template.jinja
# [INFO|trainer.py:2676] 2026-06-24 13:22:19,266 >>
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# 100%|██████████| 3/3 [00:11<00:00,  3.68s/it]
# [INFO|image_processing_base.py:260] 2026-06-24 13:22:20,576 >> Image processor saved in saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/preprocessor_config.json
# [INFO|tokenization_utils_base.py:2356] 2026-06-24 13:22:20,577 >> chat template saved in saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/chat_template.jinja
# [INFO|tokenization_utils_base.py:2525] 2026-06-24 13:22:20,578 >> tokenizer config file saved in saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2534] 2026-06-24 13:22:20,578 >> Special tokens file saved in saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/special_tokens_map.json
# [INFO|video_processing_utils.py:491] 2026-06-24 13:22:20,782 >> Video processor saved in saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/video_preprocessor_config.json
# [INFO|processing_utils.py:674] 2026-06-24 13:22:21,329 >> chat template saved in saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/chat_template.jinja
# [INFO|trainer.py:3993] 2026-06-24 13:22:21,330 >> Saving model checkpoint to saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora
# [INFO|configuration_utils.py:698] 2026-06-24 13:22:21,625 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--Qwen--Qwen2.5-VL-3B-Instruct/snapshots/66285546d2b821cf421d4f5eb2576359d3770cd3/config.json
# [INFO|configuration_utils.py:770] 2026-06-24 13:22:21,629 >> Model config Qwen2_5_VLConfig {
#   "architectures": [
#     "Qwen2_5_VLForConditionalGeneration"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 2048,
#   "image_token_id": 151655,
#   "initializer_range": 0.02,
#   "intermediate_size": 11008,
#   "max_position_embeddings": 128000,
#   "max_window_layers": 70,
#   "model_type": "qwen2_5_vl",
#   "num_attention_heads": 16,
#   "num_hidden_layers": 36,
#   "num_key_value_heads": 2,
#   "rms_norm_eps": 1e-06,
#   "rope_scaling": {
#     "mrope_section": [
#       16,
#       24,
#       24
#     ],
#     "rope_type": "default",
#     "type": "default"
#   },
#   "rope_theta": 1000000.0,
#   "sliding_window": 32768,
#   "text_config": {
#     "architectures": [
#       "Qwen2_5_VLForConditionalGeneration"
#     ],
#     "attention_dropout": 0.0,
#     "bos_token_id": 151643,
#     "eos_token_id": 151645,
#     "hidden_act": "silu",
#     "hidden_size": 2048,
#     "image_token_id": null,
#     "initializer_range": 0.02,
#     "intermediate_size": 11008,
#     "max_position_embeddings": 128000,
#     "max_window_layers": 70,
#     "model_type": "qwen2_5_vl_text",
#     "num_attention_heads": 16,
#     "num_hidden_layers": 36,
#     "num_key_value_heads": 2,
#     "rms_norm_eps": 1e-06,
#     "rope_scaling": {
#       "mrope_section": [
#         16,
#         24,
#         24
#       ],
#       "rope_type": "default",
#       "type": "default"
#     },
#     "rope_theta": 1000000.0,
#     "sliding_window": 32768,
#     "tie_word_embeddings": true,
#     "torch_dtype": "bfloat16",
#     "use_cache": true,
#     "use_sliding_window": false,
#     "video_token_id": null,
#     "vision_end_token_id": 151653,
#     "vision_start_token_id": 151652,
#     "vision_token_id": 151654,
#     "vocab_size": 151936
#   },
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.52.4",
#   "use_cache": true,
#   "use_sliding_window": false,
#   "video_token_id": 151656,
#   "vision_config": {
#     "depth": 32,
#     "fullatt_block_indexes": [
#       7,
#       15,
#       23,
#       31
#     ],
#     "hidden_act": "silu",
#     "hidden_size": 1280,
#     "in_channels": 3,
#     "in_chans": 3,
#     "initializer_range": 0.02,
#     "intermediate_size": 3420,
#     "model_type": "qwen2_5_vl",
#     "num_heads": 16,
#     "out_hidden_size": 2048,
#     "patch_size": 14,
#     "spatial_merge_size": 2,
#     "spatial_patch_size": 14,
#     "temporal_patch_size": 2,
#     "tokens_per_second": 2,
#     "window_size": 112
#   },
#   "vision_end_token_id": 151653,
#   "vision_start_token_id": 151652,
#   "vision_token_id": 151654,
#   "vocab_size": 151936
# }
#
# [INFO|tokenization_utils_base.py:2356] 2026-06-24 13:22:22,481 >> chat template saved in saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/chat_template.jinja
# [INFO|tokenization_utils_base.py:2525] 2026-06-24 13:22:22,483 >> tokenizer config file saved in saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2534] 2026-06-24 13:22:22,483 >> Special tokens file saved in saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/special_tokens_map.json
# [INFO|trainer.py:4327] 2026-06-24 13:22:22,928 >>
# ***** Running Evaluation *****
# [INFO|trainer.py:4329] 2026-06-24 13:22:22,928 >>   Num examples = 1
# [INFO|trainer.py:4332] 2026-06-24 13:22:22,928 >>   Batch size = 1
# 100%|██████████| 1/1 [00:00<00:00,  2.83it/s]
# [INFO|modelcard.py:450] 2026-06-24 13:22:24,058 >> Dropping the following result as it does not have all the necessary fields:
# {'task': {'name': 'Causal Language Modeling', 'type': 'text-generation'}, 'metrics': [{'name': 'Accuracy', 'type': 'accuracy', 'value': 0.5714285714285714}]}

# %%
# %%bash
# # 8. Full Benchmark Test (3 CROHME datasets)
# set -euo pipefail
# cd "$PROJECT_DIR"
# source "$CONDA_DIR/bin/activate" unimumer
#
# # Tìm checkpoint cuối cùng
# LAST_CKPT=$(ls -td "$OUTPUT_DIR"/checkpoint-* 2>/dev/null | head -1)
#
# if [[ -z "$LAST_CKPT" ]]; then
#   echo "ERROR: No checkpoint found in $OUTPUT_DIR"
#   exit 1
# fi
#
# echo "Testing with checkpoint: $LAST_CKPT"
# echo "Running full benchmark on 3 CROHME datasets (3,332 samples)..."
# echo ""
#
# # Chạy full benchmark
# python scripts/kaggle_full_test.py \
#   --base-model Qwen/Qwen2.5-VL-3B-Instruct \
#   --adapter-path "$LAST_CKPT" \
#   --test-datasets crohme_2014 crohme_2016 crohme_2019 \
#   --backup-dir example_data/backup \
#   --base-results-dir example_data/CROHME/results \
#   --output-dir kaggle_test_results \
#   --project-dir "$PROJECT_DIR" \
#   --batch-size 2
#
# # In summary
# echo ""
# echo "============================================================"
# echo "                    TEST SUMMARY"
# echo "============================================================"
# for dataset in crohme_2014 crohme_2016 crohme_2019; do
#   echo ""
#   echo "=== $dataset ==="
#   if [[ -f "kaggle_test_results/${dataset}_results.txt" ]]; then
#     cat "kaggle_test_results/${dataset}_results.txt" | grep -E "(Mean Edit Score|BLEU-4|Character Error Rate|Exact Match)" | head -4
#   else
#     echo "Results not found"
#   fi
# done
#
# echo ""
# echo "============================================================"
# echo "Full comparison table:"
# cat kaggle_test_results/comparison_table.txt
# Out:
# Testing with checkpoint: saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/checkpoint-3
# Running full benchmark on 3 CROHME datasets (3,332 samples)...
#
#
# ============================================================
#                     EVALUATION RESULTS
# ============================================================
#
# Dataset Statistics:
#   Total Samples: 986
#
# Core Metrics:
#   Mean Edit Score:       100.0000%
#   BLEU-4 Score:            0.0000%
#   Character Error Rate:    0.0000
#
# Error Threshold Analysis:
#   Exact Match Rate:      100.0000% (0 errors)
#   Error ≤ 1:             100.0000%
#   Error ≤ 2:             100.0000%
#   Error ≤ 3:             100.0000%
#
# Detailed Error Distribution:
#   Errors ≤ 0:    986 samples (100.00%)
#   Errors ≤ 1:    986 samples (100.00%)
#   Errors ≤ 2:    986 samples (100.00%)
#   Errors ≤ 3:    986 samples (100.00%)
#
# ============================================================
#
#
# ============================================================
#                     EVALUATION RESULTS
# ============================================================
#
# Dataset Statistics:
#   Total Samples: 1,147
#
# Core Metrics:
#   Mean Edit Score:       100.0000%
#   BLEU-4 Score:            0.0000%
#   Character Error Rate:    0.0000
#
# Error Threshold Analysis:
#   Exact Match Rate:      100.0000% (0 errors)
#   Error ≤ 1:             100.0000%
#   Error ≤ 2:             100.0000%
#   Error ≤ 3:             100.0000%
#
# Detailed Error Distribution:
#   Errors ≤ 0:  1,147 samples (100.00%)
#   Errors ≤ 1:  1,147 samples (100.00%)
#   Errors ≤ 2:  1,147 samples (100.00%)
#   Errors ≤ 3:  1,147 samples (100.00%)
#
# ============================================================
#
#
# ============================================================
#                     EVALUATION RESULTS
# ============================================================
#
# Dataset Statistics:
#   Total Samples: 1,199
#
# Core Metrics:
#   Mean Edit Score:       100.0000%
#   BLEU-4 Score:            0.0000%
#   Character Error Rate:    0.0000
#
# Error Threshold Analysis:
#   Exact Match Rate:      100.0000% (0 errors)
#   Error ≤ 1:             100.0000%
#   Error ≤ 2:             100.0000%
#   Error ≤ 3:             100.0000%
#
# Detailed Error Distribution:
#   Errors ≤ 0:  1,199 samples (100.00%)
#   Errors ≤ 1:  1,199 samples (100.00%)
#   Errors ≤ 2:  1,199 samples (100.00%)
#   Errors ≤ 3:  1,199 samples (100.00%)
#
# ============================================================
#
#
# ================================================================================
#          COMPARISON: Base Model vs Fine-tuned Model vs Paper
# ================================================================================
#
# Dataset: CROHME_2014 (986 samples)
# --------------------------------------------------------------------------------
# Metric                         Base         Fine-tuned   Delta      Paper
# --------------------------------------------------------------------------------
# Mean Edit Score                 96.55%     100.00%      +3.45%       96.31%
# BLEU-4 Score                    89.12%       0.00%     -89.12%       91.92%
# Character Error Rate             0.0396     0.0000    -0.0396     0.0273
# Exact Match Rate                82.66%     100.00%     +17.34%       82.05%
#
# Dataset: CROHME_2016 (1147 samples)
# --------------------------------------------------------------------------------
# Metric                         Base         Fine-tuned   Delta      Paper
# --------------------------------------------------------------------------------
# Mean Edit Score                 96.55%     100.00%      +3.45%       96.35%
# BLEU-4 Score                    94.13%       0.00%     -94.13%       93.76%
# Character Error Rate             0.0143     0.0000    -0.0143     0.0150
# Exact Match Rate                78.90%     100.00%     +21.10%       77.94%
#
# Dataset: CROHME_2019 (1199 samples)
# --------------------------------------------------------------------------------
# Metric                         Base         Fine-tuned   Delta      Paper
# --------------------------------------------------------------------------------
# Mean Edit Score                 96.84%     100.00%      +3.16%       96.74%
# BLEU-4 Score                    94.97%       0.00%     -94.97%       94.91%
# Character Error Rate             0.0123     0.0000    -0.0123     0.0127
# Exact Match Rate                79.82%     100.00%     +20.18%       79.23%
#
# ================================================================================
# OVERALL SUMMARY (All 3 CROHME datasets)
# ================================================================================
#
# Metric                         Base (avg)   Fine-tuned (avg) Delta      Paper (avg)
# --------------------------------------------------------------------------------
# Mean Edit Score                 96.65%     100.00%         +3.35%       96.47%
# BLEU-4 Score                    92.74%       0.00%        -92.74%       93.53%
# Character Error Rate             0.0221     0.0000         -0.0221 0.018333333333333337
# Exact Match Rate                80.46%     100.00%        +19.54%       79.74%
#
# ================================================================================
# Conclusion: Fine-tuned model shows +3.35% improvement
#             in Mean Edit Score compared to base model.
# ================================================================================
#
# ============================================================
#                     TEST SUMMARY
# ============================================================
#
# === crohme_2014 ===
#   Mean Edit Score:       100.0000%
#   BLEU-4 Score:            0.0000%
#   Character Error Rate:    0.0000
#   Exact Match Rate:      100.0000% (0 errors)
#
# === crohme_2016 ===
#   Mean Edit Score:       100.0000%
#   BLEU-4 Score:            0.0000%
#   Character Error Rate:    0.0000
#   Exact Match Rate:      100.0000% (0 errors)
#
# === crohme_2019 ===
#   Mean Edit Score:       100.0000%
#   BLEU-4 Score:            0.0000%
#   Character Error Rate:    0.0000
#   Exact Match Rate:      100.0000% (0 errors)
#
# ============================================================
# Full comparison table:
# ================================================================================
#          COMPARISON: Base Model vs Fine-tuned Model vs Paper
# ================================================================================
#
# Dataset: CROHME_2014 (986 samples)
# --------------------------------------------------------------------------------
# Metric                         Base         Fine-tuned   Delta      Paper
# --------------------------------------------------------------------------------
# Mean Edit Score                 96.55%     100.00%      +3.45%       96.31%
# BLEU-4 Score                    89.12%       0.00%     -89.12%       91.92%
# Character Error Rate             0.0396     0.0000    -0.0396     0.0273
# Exact Match Rate                82.66%     100.00%     +17.34%       82.05%
#
# Dataset: CROHME_2016 (1147 samples)
# --------------------------------------------------------------------------------
# Metric                         Base         Fine-tuned   Delta      Paper
# --------------------------------------------------------------------------------
# Mean Edit Score                 96.55%     100.00%      +3.45%       96.35%
# BLEU-4 Score                    94.13%       0.00%     -94.13%       93.76%
# Character Error Rate             0.0143     0.0000    -0.0143     0.0150
# Exact Match Rate                78.90%     100.00%     +21.10%       77.94%
#
# Dataset: CROHME_2019 (1199 samples)
# --------------------------------------------------------------------------------
# Metric                         Base         Fine-tuned   Delta      Paper
# --------------------------------------------------------------------------------
# Mean Edit Score                 96.84%     100.00%      +3.16%       96.74%
# BLEU-4 Score                    94.97%       0.00%     -94.97%       94.91%
# Character Error Rate             0.0123     0.0000    -0.0123     0.0127
# Exact Match Rate                79.82%     100.00%     +20.18%       79.23%
#
# ================================================================================
# OVERALL SUMMARY (All 3 CROHME datasets)
# ================================================================================
#
# Metric                         Base (avg)   Fine-tuned (avg) Delta      Paper (avg)
# --------------------------------------------------------------------------------
# Mean Edit Score                 96.65%     100.00%         +3.35%       96.47%
# BLEU-4 Score                    92.74%       0.00%        -92.74%       93.53%
# Character Error Rate             0.0221     0.0000         -0.0221 0.018333333333333337
# Exact Match Rate                80.46%     100.00%        +19.54%       79.74%
#
# ================================================================================
# Conclusion: Fine-tuned model shows +3.35% improvement
#             in Mean Edit Score compared to base model.
# ================================================================================
# 2026-06-24 13:22:30,345 [INFO] ================================================================================
# 2026-06-24 13:22:30,345 [INFO] Starting full benchmark test on 3 CROHME datasets
# 2026-06-24 13:22:30,345 [INFO] ================================================================================
# 2026-06-24 13:22:30,345 [INFO]
# 2026-06-24 13:22:30,345 [INFO] ================================================================================
# 2026-06-24 13:22:30,345 [INFO] Testing CROHME_2014...
# 2026-06-24 13:22:30,345 [INFO] ================================================================================
# 2026-06-24 13:22:30,345 [INFO] Running: /kaggle/working/miniconda/envs/unimumer/bin/python /kaggle/working/test-unimer/scripts/kaggle_test_adapter.py --base-model Qwen/Qwen2.5-VL-3B-Instruct --adapter-path saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/checkpoint-3 --test-data /kaggle/working/test-unimer/example_data/backup/crohme_2014.json --output-dir kaggle_test_results --project-dir /kaggle/working/test-unimer --batch-size 2
# 2026-06-24 13:22:30,396 [INFO] ============================================================
# 2026-06-24 13:22:30,396 [INFO] Testing dataset: crohme_2014
# 2026-06-24 13:22:30,396 [INFO] ============================================================
# 2026-06-24 13:22:30,396 [INFO] Converting /kaggle/working/test-unimer/example_data/backup/crohme_2014.json to prompts format...
# 2026-06-24 13:22:30,428 [INFO] ✓ Converted 986 samples → kaggle_test_results/crohme_2014_prompts.json
# 2026-06-24 13:22:30,429 [INFO] Running inference with Transformers + PEFT...
# 2026-06-24 13:22:36,382 [INFO] Using Qwen2VLForConditionalGeneration
# 2026-06-24 13:22:36,382 [INFO] Loading base model: Qwen/Qwen2.5-VL-3B-Instruct
# You are using a model of type qwen2_5_vl to instantiate a model of type qwen2_vl. This is not supported for all configurations of models and can yield errors.
# Loading checkpoint shards: 100%|██████████| 2/2 [00:07<00:00,  3.56s/it]
# Some weights of Qwen2VLForConditionalGeneration were not initialized from the model checkpoint at Qwen/Qwen2.5-VL-3B-Instruct and are newly initialized: ['model.visual.blocks.0.mlp.fc1.bias', 'model.visual.blocks.0.mlp.fc1.weight', 'model.visual.blocks.0.mlp.fc2.bias', 'model.visual.blocks.0.mlp.fc2.weight', 'model.visual.blocks.0.norm1.bias', 'model.visual.blocks.0.norm2.bias', 'model.visual.blocks.1.mlp.fc1.bias', 'model.visual.blocks.1.mlp.fc1.weight', 'model.visual.blocks.1.mlp.fc2.bias', 'model.visual.blocks.1.mlp.fc2.weight', 'model.visual.blocks.1.norm1.bias', 'model.visual.blocks.1.norm2.bias', 'model.visual.blocks.10.mlp.fc1.bias', 'model.visual.blocks.10.mlp.fc1.weight', 'model.visual.blocks.10.mlp.fc2.bias', 'model.visual.blocks.10.mlp.fc2.weight', 'model.visual.blocks.10.norm1.bias', 'model.visual.blocks.10.norm2.bias', 'model.visual.blocks.11.mlp.fc1.bias', 'model.visual.blocks.11.mlp.fc1.weight', 'model.visual.blocks.11.mlp.fc2.bias', 'model.visual.blocks.11.mlp.fc2.weight', 'model.visual.blocks.11.norm1.bias', 'model.visual.blocks.11.norm2.bias', 'model.visual.blocks.12.mlp.fc1.bias', 'model.visual.blocks.12.mlp.fc1.weight', 'model.visual.blocks.12.mlp.fc2.bias', 'model.visual.blocks.12.mlp.fc2.weight', 'model.visual.blocks.12.norm1.bias', 'model.visual.blocks.12.norm2.bias', 'model.visual.blocks.13.mlp.fc1.bias', 'model.visual.blocks.13.mlp.fc1.weight', 'model.visual.blocks.13.mlp.fc2.bias', 'model.visual.blocks.13.mlp.fc2.weight', 'model.visual.blocks.13.norm1.bias', 'model.visual.blocks.13.norm2.bias', 'model.visual.blocks.14.mlp.fc1.bias', 'model.visual.blocks.14.mlp.fc1.weight', 'model.visual.blocks.14.mlp.fc2.bias', 'model.visual.blocks.14.mlp.fc2.weight', 'model.visual.blocks.14.norm1.bias', 'model.visual.blocks.14.norm2.bias', 'model.visual.blocks.15.mlp.fc1.bias', 'model.visual.blocks.15.mlp.fc1.weight', 'model.visual.blocks.15.mlp.fc2.bias', 'model.visual.blocks.15.mlp.fc2.weight', 'model.visual.blocks.15.norm1.bias', 'model.visual.blocks.15.norm2.bias', 'model.visual.blocks.16.mlp.fc1.bias', 'model.visual.blocks.16.mlp.fc1.weight', 'model.visual.blocks.16.mlp.fc2.bias', 'model.visual.blocks.16.mlp.fc2.weight', 'model.visual.blocks.16.norm1.bias', 'model.visual.blocks.16.norm2.bias', 'model.visual.blocks.17.mlp.fc1.bias', 'model.visual.blocks.17.mlp.fc1.weight', 'model.visual.blocks.17.mlp.fc2.bias', 'model.visual.blocks.17.mlp.fc2.weight', 'model.visual.blocks.17.norm1.bias', 'model.visual.blocks.17.norm2.bias', 'model.visual.blocks.18.mlp.fc1.bias', 'model.visual.blocks.18.mlp.fc1.weight', 'model.visual.blocks.18.mlp.fc2.bias', 'model.visual.blocks.18.mlp.fc2.weight', 'model.visual.blocks.18.norm1.bias', 'model.visual.blocks.18.norm2.bias', 'model.visual.blocks.19.mlp.fc1.bias', 'model.visual.blocks.19.mlp.fc1.weight', 'model.visual.blocks.19.mlp.fc2.bias', 'model.visual.blocks.19.mlp.fc2.weight', 'model.visual.blocks.19.norm1.bias', 'model.visual.blocks.19.norm2.bias', 'model.visual.blocks.2.mlp.fc1.bias', 'model.visual.blocks.2.mlp.fc1.weight', 'model.visual.blocks.2.mlp.fc2.bias', 'model.visual.blocks.2.mlp.fc2.weight', 'model.visual.blocks.2.norm1.bias', 'model.visual.blocks.2.norm2.bias', 'model.visual.blocks.20.mlp.fc1.bias', 'model.visual.blocks.20.mlp.fc1.weight', 'model.visual.blocks.20.mlp.fc2.bias', 'model.visual.blocks.20.mlp.fc2.weight', 'model.visual.blocks.20.norm1.bias', 'model.visual.blocks.20.norm2.bias', 'model.visual.blocks.21.mlp.fc1.bias', 'model.visual.blocks.21.mlp.fc1.weight', 'model.visual.blocks.21.mlp.fc2.bias', 'model.visual.blocks.21.mlp.fc2.weight', 'model.visual.blocks.21.norm1.bias', 'model.visual.blocks.21.norm2.bias', 'model.visual.blocks.22.mlp.fc1.bias', 'model.visual.blocks.22.mlp.fc1.weight', 'model.visual.blocks.22.mlp.fc2.bias', 'model.visual.blocks.22.mlp.fc2.weight', 'model.visual.blocks.22.norm1.bias', 'model.visual.blocks.22.norm2.bias', 'model.visual.blocks.23.mlp.fc1.bias', 'model.visual.blocks.23.mlp.fc1.weight', 'model.visual.blocks.23.mlp.fc2.bias', ' ...
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 2026-06-24 13:23:06,756 [INFO] Loading LoRA adapter: saves/qwen2.5_vl-3b/qlora/sft/standred/uni-mumer_qlora/checkpoint-3
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# You have video processor config saved in `preprocessor.json` file which is deprecated. Video processor configs should be saved in their own `video_preprocessor.json` file. You can rename the file or load and save the processor back which renames it automatically. Loading from `preprocessor.json` will be removed in v5.0.
# 2026-06-24 13:23:11,494 [INFO] Loaded 986 samples from kaggle_test_results/crohme_2014_prompts.json
# Inference:   0%|          | 0/493 [00:00<?, ?it/s]2026-06-24 13:23:11,496 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,496 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,496 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,496 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,496 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,496 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,496 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,496 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,496 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,496 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,496 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,496 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,496 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,497 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,497 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,497 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,497 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,497 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,497 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,497 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,497 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,497 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,497 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,497 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,497 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,497 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,497 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,497 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,497 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,497 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,498 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,498 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,498 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,498 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,498 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,498 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,498 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,498 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,498 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,498 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,498 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,498 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,498 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,498 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,498 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,498 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,499 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,499 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,499 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,499 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,499 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,499 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,499 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,499 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,499 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,499 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,499 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,499 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,499 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,499 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,499 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,499 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,500 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,500 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,500 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,500 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,500 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,500 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,500 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,500 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,500 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,500 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,500 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,500 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,500 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,500 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,500 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,500 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,501 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,501 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,501 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,501 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,501 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,501 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,501 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,501 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,501 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,501 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,501 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,501 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,501 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,501 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,501 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,501 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,501 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,502 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,502 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,502 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,502 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,502 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,502 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,502 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,502 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,502 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,502 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,502 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,502 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,502 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,502 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,502 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,502 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,503 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,503 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,503 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,503 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,503 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,503 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,503 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,503 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,503 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,503 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,503 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,503 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,503 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,503 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,503 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,503 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,504 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,504 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,504 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,504 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,504 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,504 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,504 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,504 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,504 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,504 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,504 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,504 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,504 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,504 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,504 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,504 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,504 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,504 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,504 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,505 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,505 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,505 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,505 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,505 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,505 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,505 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,505 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,505 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,505 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,505 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,505 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,505 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,505 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,505 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,505 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,505 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,505 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,506 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,506 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,506 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,506 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,506 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,506 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,506 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,506 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,506 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,506 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,506 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,506 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,506 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,506 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,506 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,506 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,507 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,507 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,507 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,507 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,507 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,507 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,507 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,507 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,507 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,507 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,507 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,507 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,507 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,507 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,507 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,507 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,508 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,508 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,508 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,508 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,508 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,508 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,508 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,508 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,508 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,508 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,508 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,508 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,508 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,508 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,508 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,508 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,508 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,508 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,509 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,509 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,509 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,509 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,509 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,509 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,509 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,509 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,509 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,509 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,509 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,509 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,509 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,509 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,509 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,509 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,509 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,510 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,510 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,510 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,510 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:23:11,510 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# ...
# 2026-06-24 13:24:36,960 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,960 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,960 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,960 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,960 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,960 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,960 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,961 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,961 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,961 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,961 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,961 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,961 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,961 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,961 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,961 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,961 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,961 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,962 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,962 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,962 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,962 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,962 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,962 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,962 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,962 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,962 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,963 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,963 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,963 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,963 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,963 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,963 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,963 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,963 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,963 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,963 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,964 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,964 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,964 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,964 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,964 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,964 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,964 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,964 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,965 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,965 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,965 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,965 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,965 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,965 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,965 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,965 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,966 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,966 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,966 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,966 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,966 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,966 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,966 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,966 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,966 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,967 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,967 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,967 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,967 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,967 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,967 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,967 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,967 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,968 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,968 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,968 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,968 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,968 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,968 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,968 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,968 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,968 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,969 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,969 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,969 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,969 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,969 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,969 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,969 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,969 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,970 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,970 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,970 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,970 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,970 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,970 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,971 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,971 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,971 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,971 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,971 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,971 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,971 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,971 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,972 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,972 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,972 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,972 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# 2026-06-24 13:24:36,972 [ERROR] Error processing /kaggle/working/test-unimer: [Errno 21] Is a directory: '/kaggle/working/test-unimer'
# Inference: 100%|██████████| 600/600 [00:00<00:00, 7741.19it/s]
# 2026-06-24 13:24:36,981 [INFO] ✓ Saved 1199 predictions → kaggle_test_results/crohme_2019_pred.json
# 2026-06-24 13:24:37,071 [INFO] Evaluating predictions: kaggle_test_results/crohme_2019_pred.json
# 2026-06-24 13:24:37,263 [INFO] Loading data from kaggle_test_results/crohme_2019_pred.json
# 2026-06-24 13:24:37,265 [INFO] Processing 1199 samples
# 2026-06-24 13:24:37,291 [INFO] Saving results to kaggle_test_results/crohme_2019_results.txt
# 2026-06-24 13:24:37,291 [INFO] Evaluation completed successfully
# 2026-06-24 13:24:37,291 [INFO] ✓ Evaluation complete → kaggle_test_results/crohme_2019_results.txt
# 2026-06-24 13:24:37,291 [INFO] ============================================================
# 2026-06-24 13:24:37,292 [INFO] ✓ Test complete!
# 2026-06-24 13:24:37,292 [INFO]   Predictions: kaggle_test_results/crohme_2019_pred.json
# 2026-06-24 13:24:37,292 [INFO]   Results: kaggle_test_results/crohme_2019_results.txt
# 2026-06-24 13:24:37,292 [INFO] ============================================================
# 2026-06-24 13:24:38,808 [INFO] ✓ Comparison table saved → kaggle_test_results/comparison_table.txt
# 2026-06-24 13:24:38,808 [INFO]
# 2026-06-24 13:24:38,808 [INFO] ================================================================================
# 2026-06-24 13:24:38,808 [INFO] ✓ Full benchmark test complete!
# 2026-06-24 13:24:38,808 [INFO]   Results directory: kaggle_test_results
# 2026-06-24 13:24:38,808 [INFO]   Comparison table: kaggle_test_results/comparison_table.txt
# 2026-06-24 13:24:38,809 [INFO] ================================================================================

# %%
# %%bash
# # 9. Upload artifacts và test results lên DagsHub
# set -euo pipefail
# cd "$PROJECT_DIR"
# source "$CONDA_DIR/bin/activate" unimumer
#
# # Upload model checkpoint và config
# python scripts/dagshub_logger.py upload \
#   --experiment "$MLFLOW_EXPERIMENT_NAME" \
#   --run-uuid "$RUN_UUID" \
#   --config "$YAML_CONFIG" \
#   --output-dir "$OUTPUT_DIR" \
#   --project-dir "$PROJECT_DIR" \
#   --notebook "$NOTEBOOK_PATH"
#
# # Upload test results (nếu có)
# if [[ -d "kaggle_test_results" ]]; then
#   echo ""
#   echo "Uploading test results to DagsHub..."
#
#   # Tạo archive của test results
#   tar -czf kaggle_test_results.tar.gz kaggle_test_results/
#
#   python scripts/dagshub_logger.py upload \
#     --experiment "$MLFLOW_EXPERIMENT_NAME" \
#     --run-uuid "$RUN_UUID" \
#     --artifact-path kaggle_test_results.tar.gz \
#     --artifact-type "test_results"
#
#   echo "✓ Test results uploaded"
# fi
# Out:
# 🏃 View run uni-mumer-99f4ad6d at: https://dagshub.com/NhatPot/test-unimer.mlflow/#/experiments/1/runs/c80a0cb7c28647ae97c30df97b365328
# 🧪 View experiment at: https://dagshub.com/NhatPot/test-unimer.mlflow/#/experiments/1
# Uploaded 2 artifact groups to DagsHub
# Run: https://dagshub.com/NhatPot/test-unimer.mlflow/#/experiments/1/runs/c80a0cb7c28647ae97c30df97b365328
#
# Uploading test results to DagsHub...
# usage: dagshub_logger.py upload [-h] --experiment EXPERIMENT --run-uuid
#                                 RUN_UUID --config CONFIG --output-dir
#                                 OUTPUT_DIR [--project-dir PROJECT_DIR]
#                                 --notebook NOTEBOOK
# dagshub_logger.py upload: error: the following arguments are required: --config, --output-dir, --notebook
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_58/3004011575.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('bash', '', '# 9. Upload artifacts và test results lên DagsHub\nset -euo pipefail\ncd "$PROJECT_DIR"\nsource "$CONDA_DIR/bin/activate" unimumer\n\n# Upload model checkpoint và config\npython scripts/dagshub_logger.py upload \\\n  --experiment "$MLFLOW_EXPERIMENT_NAME" \\\n  --run-uuid "$RUN_UUID" \\\n  --config "$YAML_CONFIG" \\\n  --output-dir "$OUTPUT_DIR" \\\n  --project-dir "$PROJECT_DIR" \\\n  --notebook "$NOTEBOOK_PATH"\n\n# Upload test results (nếu có)\nif [[ -d "kaggle_test_results" ]]; then\n  echo ""\n  echo "Uploading test results to DagsHub..."\n  \n  # Tạo archive của test results\n  tar -czf kaggle_test_results.tar.gz kaggle_test_results/\n  \n  python scripts/dagshub_logger.py upload \\\n    --experiment "$MLFLOW_EXPERIMENT_NAME" \\\n    --run-uuid "$RUN_UUID" \\\n    --artifact-path kaggle_test_results.tar.gz \\\n    --artifact-type "test_results"\n  \n  echo "✓ Test results uploaded"\nfi\n')
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# /usr/local/lib/python3.12/dist-packages/decorator/__init__.py in fun(*args, **kw)
#     245             if not kwsyntax:
#     246                 args, kw = fix(args, kw, sig)
# --> 247             return caller(func, *(extras + args), **kw)
#     248
#     249     fun.__doc__ = func.__doc__
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'# 9. Upload artifacts v\xc3\xa0 test results l\xc3\xaan DagsHub\nset -euo pipefail\ncd "$PROJECT_DIR"\nsource "$CONDA_DIR/bin/activate" unimumer\n\n# Upload model checkpoint v\xc3\xa0 config\npython scripts/dagshub_logger.py upload \\\n  --experiment "$MLFLOW_EXPERIMENT_NAME" \\\n  --run-uuid "$RUN_UUID" \\\n  --config "$YAML_CONFIG" \\\n  --output-dir "$OUTPUT_DIR" \\\n  --project-dir "$PROJECT_DIR" \\\n  --notebook "$NOTEBOOK_PATH"\n\n# Upload test results (n\xe1\xba\xbfu c\xc3\xb3)\nif [[ -d "kaggle_test_results" ]]; then\n  echo ""\n  echo "Uploading test results to DagsHub..."\n  \n  # T\xe1\xba\xa1o archive c\xe1\xbb\xa7a test results\n  tar -czf kaggle_test_results.tar.gz kaggle_test_results/\n  \n  python scripts/dagshub_logger.py upload \\\n    --experiment "$MLFLOW_EXPERIMENT_NAME" \\\n    --run-uuid "$RUN_UUID" \\\n    --artifact-path kaggle_test_results.tar.gz \\\n    --artifact-type "test_results"\n  \n  echo "\xe2\x9c\x93 Test results uploaded"\nfi\n'' returned non-zero exit status 2.
